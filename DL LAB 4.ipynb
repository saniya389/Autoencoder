# %%
import pandas as pd
import numpy as np
import pickle
import matplotlib.pyplot as plt
from scipy import stats
import tensorflow as tf
import seaborn as sns
from pylab import rcParams
from sklearn.model_selection import train_test_split
from keras.models import Model, load_model
from keras.layers import Input, Dense
from keras.callbacks import ModelCheckpoint, TensorBoard
from keras import regularizers

# %matplotlib inline

sns.set(style='whitegrid', palette='muted', font_scale=1.5)

rcParams['figure.figsize'] = 14, 8

RANDOM_SEED = 42
LABELS = ["Normal", "Fraud"]
# Out:
# WARNING:tensorflow:From C:\Users\shaik\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
df =  pd.read_csv("creditcard.csv")

# %%
count_classes = pd.value_counts(df['Class'], sort = True)
count_classes.plot(kind = 'bar', rot=0)
plt.title("Transaction class distribution")
plt.xticks(range(2), LABELS)
plt.xlabel("Class")
plt.ylabel("Frequency");

# %%
from sklearn.preprocessing import StandardScaler

data = df.drop(['Time'], axis=1)

data['Amount'] = StandardScaler().fit_transform(data['Amount'].values.reshape(-1, 1))

# %%
X_train, X_test = train_test_split(data, test_size=0.2, random_state=RANDOM_SEED)
X_train = X_train[X_train.Class == 0]
X_train = X_train.drop(['Class'], axis=1)

y_test = X_test['Class']
X_test = X_test.drop(['Class'], axis=1)

X_train = X_train.values
X_test = X_test.values

# %%
input_dim = X_train.shape[1]
encoding_dim = 14

# %%
input_layer = Input(shape=(input_dim, ))

encoder = Dense(encoding_dim, activation="tanh", 
                activity_regularizer=regularizers.l1(10e-5))(input_layer)
encoder = Dense(int(encoding_dim / 2), activation="relu")(encoder)

decoder = Dense(int(encoding_dim / 2), activation='tanh')(encoder)
decoder = Dense(input_dim, activation='relu')(decoder)

autoencoder = Model(inputs=input_layer, outputs=decoder)
# Out:
# WARNING:tensorflow:From C:\Users\shaik\anaconda3\Lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From C:\Users\shaik\anaconda3\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.

# %%
nb_epoch = 100
batch_size = 32
early_stop = tf.keras.callbacks. EarlyStopping( monitor= 'val_loss', min_delta=0.0001, patience=10, verbose=1, mode='min', 
                                               restore_best_weights=True)

autoencoder.compile(optimizer='adam', 
                    loss='mean_squared_error', 
                    metrics=['accuracy'])

checkpointer = ModelCheckpoint(filepath="model.h5",
                               verbose=0,
                               save_best_only=True)
tensorboard = TensorBoard(log_dir='./logs',
                          histogram_freq=0,
                          write_graph=True,
                          write_images=True)

history = autoencoder.fit(X_train, X_train,
                    epochs=nb_epoch,
                    batch_size=batch_size,
                    shuffle=True,
                    validation_data=(X_test, X_test),
                    verbose=1,
                    callbacks=[checkpointer, early_stop]).history
# Out:
# WARNING:tensorflow:From C:\Users\shaik\anaconda3\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Epoch 1/100
# WARNING:tensorflow:From C:\Users\shaik\anaconda3\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 7108/7108 [==============================] - 31s 4ms/step - loss: 0.8095 - accuracy: 0.5805 - val_loss: 0.7853 - val_accuracy: 0.6382
# Epoch 2/100
#   24/7108 [..............................] - ETA: 19s - loss: 0.6806 - accuracy: 0.6523
# C:\Users\shaik\anaconda3\Lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 7108/7108 [==============================] - 27s 4ms/step - loss: 0.7417 - accuracy: 0.6605 - val_loss: 0.7667 - val_accuracy: 0.6703
# Epoch 3/100
# 7108/7108 [==============================] - 29s 4ms/step - loss: 0.7297 - accuracy: 0.6747 - val_loss: 0.7595 - val_accuracy: 0.6778
# Epoch 4/100
# 7108/7108 [==============================] - 28s 4ms/step - loss: 0.7235 - accuracy: 0.6763 - val_loss: 0.7553 - val_accuracy: 0.6802
# Epoch 5/100
# 7108/7108 [==============================] - 29s 4ms/step - loss: 0.7198 - accuracy: 0.6773 - val_loss: 0.7534 - val_accuracy: 0.6820
# Epoch 6/100
# 7108/7108 [==============================] - 28s 4ms/step - loss: 0.7178 - accuracy: 0.6770 - val_loss: 0.7517 - val_accuracy: 0.6796
# Epoch 7/100
# 7108/7108 [==============================] - 27s 4ms/step - loss: 0.7165 - accuracy: 0.6774 - val_loss: 0.7511 - val_accuracy: 0.6752
# Epoch 8/100
# 7108/7108 [==============================] - 25s 4ms/step - loss: 0.7153 - accuracy: 0.6773 - val_loss: 0.7500 - val_accuracy: 0.6813
# Epoch 9/100
# 7108/7108 [==============================] - 28s 4ms/step - loss: 0.7142 - accuracy: 0.6793 - val_loss: 0.7493 - val_accuracy: 0.6845
# Epoch 10/100
# 7108/7108 [==============================] - 28s 4ms/step - loss: 0.7130 - accuracy: 0.6808 - val_loss: 0.7470 - val_accuracy: 0.6780
# Epoch 11/100
# 7108/7108 [==============================] - 27s 4ms/step - loss: 0.7122 - accuracy: 0.6826 - val_loss: 0.7478 - val_accuracy: 0.6772
# Epoch 12/100
# 7108/7108 [==============================] - 27s 4ms/step - loss: 0.7119 - accuracy: 0.6820 - val_loss: 0.7489 - val_accuracy: 0.6789
# Epoch 13/100
# 7108/7108 [==============================] - 27s 4ms/step - loss: 0.7100 - accuracy: 0.6817 - val_loss: 0.7449 - val_accuracy: 0.6804
# Epoch 14/100
# 7108/7108 [==============================] - 27s 4ms/step - loss: 0.7091 - accuracy: 0.6845 - val_loss: 0.7432 - val_accuracy: 0.6899
# Epoch 15/100
# 7108/7108 [==============================] - 26s 4ms/step - loss: 0.7086 - accuracy: 0.6858 - val_loss: 0.7445 - val_accuracy: 0.6843
# Epoch 16/100
# 7108/7108 [==============================] - 26s 4ms/step - loss: 0.7077 - accuracy: 0.6862 - val_loss: 0.7432 - val_accuracy: 0.6850
# Epoch 17/100
# 7108/7108 [==============================] - 26s 4ms/step - loss: 0.7073 - accuracy: 0.6866 - val_loss: 0.7421 - val_accuracy: 0.6929
# Epoch 18/100
# 7108/7108 [==============================] - 29s 4ms/step - loss: 0.7070 - accuracy: 0.6875 - val_loss: 0.7431 - val_accuracy: 0.6891
# Epoch 19/100
# 7108/7108 [==============================] - 27s 4ms/step - loss: 0.7067 - accuracy: 0.6880 - val_loss: 0.7421 - val_accuracy: 0.6924
# Epoch 20/100
# 7108/7108 [==============================] - 28s 4ms/step - loss: 0.7065 - accuracy: 0.6886 - val_loss: 0.7423 - val_accuracy: 0.6909
# Epoch 21/100
# 7108/7108 [==============================] - 27s 4ms/step - loss: 0.7061 - accuracy: 0.6888 - val_loss: 0.7440 - val_accuracy: 0.6953
# Epoch 22/100
# 7108/7108 [==============================] - 27s 4ms/step - loss: 0.7061 - accuracy: 0.6877 - val_loss: 0.7422 - val_accuracy: 0.6943
# Epoch 23/100
# 7108/7108 [==============================] - 28s 4ms/step - loss: 0.7058 - accuracy: 0.6883 - val_loss: 0.7421 - val_accuracy: 0.6917
# Epoch 24/100
# 7108/7108 [==============================] - 29s 4ms/step - loss: 0.7059 - accuracy: 0.6887 - val_loss: 0.7417 - val_accuracy: 0.6887
# Epoch 25/100
# 7108/7108 [==============================] - 29s 4ms/step - loss: 0.7060 - accuracy: 0.6883 - val_loss: 0.7418 - val_accuracy: 0.6919
# Epoch 26/100
# 7108/7108 [==============================] - 30s 4ms/step - loss: 0.7054 - accuracy: 0.6891 - val_loss: 0.7467 - val_accuracy: 0.6816
# Epoch 27/100
# 7108/7108 [==============================] - 29s 4ms/step - loss: 0.7053 - accuracy: 0.6888 - val_loss: 0.7412 - val_accuracy: 0.6895
# Epoch 28/100
# 7108/7108 [==============================] - 28s 4ms/step - loss: 0.7055 - accuracy: 0.6887 - val_loss: 0.7416 - val_accuracy: 0.6891
# Epoch 29/100
# 7108/7108 [==============================] - 29s 4ms/step - loss: 0.7051 - accuracy: 0.6885 - val_loss: 0.7415 - val_accuracy: 0.6943
# Epoch 30/100
# 7108/7108 [==============================] - 27s 4ms/step - loss: 0.7047 - accuracy: 0.6885 - val_loss: 0.7435 - val_accuracy: 0.6854
# Epoch 31/100
# 7108/7108 [==============================] - 28s 4ms/step - loss: 0.7046 - accuracy: 0.6890 - val_loss: 0.7410 - val_accuracy: 0.6838
# Epoch 32/100
# 7108/7108 [==============================] - 28s 4ms/step - loss: 0.7052 - accuracy: 0.6881 - val_loss: 0.7391 - val_accuracy: 0.6947
# Epoch 33/100
# 7108/7108 [==============================] - 26s 4ms/step - loss: 0.7044 - accuracy: 0.6891 - val_loss: 0.7419 - val_accuracy: 0.6945
# Epoch 34/100
# 7108/7108 [==============================] - 28s 4ms/step - loss: 0.7045 - accuracy: 0.6890 - val_loss: 0.7440 - val_accuracy: 0.6846
# Epoch 35/100
# 7108/7108 [==============================] - 27s 4ms/step - loss: 0.7044 - accuracy: 0.6896 - val_loss: 0.7410 - val_accuracy: 0.6896
# Epoch 36/100
# 7108/7108 [==============================] - 28s 4ms/step - loss: 0.7043 - accuracy: 0.6888 - val_loss: 0.7396 - val_accuracy: 0.6964
# Epoch 37/100
# 7108/7108 [==============================] - 26s 4ms/step - loss: 0.7044 - accuracy: 0.6890 - val_loss: 0.7407 - val_accuracy: 0.6911
# Epoch 38/100
# 7108/7108 [==============================] - 25s 4ms/step - loss: 0.7040 - accuracy: 0.6902 - val_loss: 0.7397 - val_accuracy: 0.6961
# Epoch 39/100
# 7108/7108 [==============================] - 25s 4ms/step - loss: 0.7041 - accuracy: 0.6895 - val_loss: 0.7410 - val_accuracy: 0.6892
# Epoch 40/100
# 7108/7108 [==============================] - 26s 4ms/step - loss: 0.7041 - accuracy: 0.6897 - val_loss: 0.7391 - val_accuracy: 0.6921
# Epoch 41/100
# 7108/7108 [==============================] - 29s 4ms/step - loss: 0.7041 - accuracy: 0.6895 - val_loss: 0.7393 - val_accuracy: 0.6977
# Epoch 42/100
# 7094/7108 [============================>.] - ETA: 0s - loss: 0.7040 - accuracy: 0.6902Restoring model weights from the end of the best epoch: 32.
# 7108/7108 [==============================] - 28s 4ms/step - loss: 0.7040 - accuracy: 0.6904 - val_loss: 0.7395 - val_accuracy: 0.6871
# Epoch 42: early stopping

# %%
plt.plot(history['loss'])
plt.plot(history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right');

# %%
predictions = autoencoder.predict(X_test)
# Out:
# 1781/1781 [==============================] - 5s 3ms/step

# %%
mse = np.mean(np.power(X_test - predictions, 2), axis=1)
error_df = pd.DataFrame({'reconstruction_error': mse,
                        'true_class': y_test})

# %%
error_df.describe()
# Out:
#        reconstruction_error    true_class
# count          56962.000000  56962.000000
# mean               0.738182      0.001720
# std                3.448406      0.041443
# min                0.049132      0.000000
# 25%                0.244308      0.000000
# 50%                0.382629      0.000000
# 75%                0.608758      0.000000
# max              260.245460      1.000000

# %%
threshold = 50
groups = error_df.groupby('true_class')
fig, ax = plt.subplots()

for name, group in groups:
    ax.plot(group.index, group.reconstruction_error, marker='o', ms=3.5, linestyle='',
            label= "Fraud" if name == 1 else "Normal")
ax.hlines(threshold, ax.get_xlim()[0], ax.get_xlim()[1], colors="r", zorder=100, label='Threshold')
ax.legend()
plt.title("Reconstruction error for different classes")
plt.ylabel("Reconstruction error")
plt.xlabel("Data point index")
plt.show();

# %%
from sklearn.metrics import confusion_matrix,recall_score,accuracy_score,precision_score

# %%
y_pred = [1 if e > threshold else 0 for e in error_df.reconstruction_error.values]
conf_matrix = confusion_matrix(error_df.true_class, y_pred)

plt.figure(figsize=(12, 12))
sns.heatmap(conf_matrix, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="d");
plt.title("Confusion matrix")
plt.ylabel('True class')
plt.xlabel('Predicted class')
plt.show()

# %%
error_df['pred'] = y_pred

# %%
# print Accuracy, precision and recall print(" Accuracy:

print("Accuracy:",accuracy_score (error_df['true_class'],error_df['pred'])) 
print(" Recall:",recall_score(error_df['true_class'],error_df['pred']))
print(" Precision:",precision_score(error_df['true_class'],error_df['pred']))
# Out:
# Accuracy: 0.9983848881710614
#  Recall: 0.25510204081632654
#  Precision: 0.5681818181818182
